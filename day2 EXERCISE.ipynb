# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative Artificial Intelligence (AI) has numerous business applications across various industries, including:
#
# 1. **Content Generation**: Generative AI can create high-quality content such as articles, social media posts, product descriptions, and even entire books. This reduces the need for human writers and allows companies to produce large volumes of content quickly.
# 2. **Image and Video Creation**: Generative AI can generate images and videos that are indistinguishable from those created by humans. This has applications in advertising, marketing, and entertainment industries.
# 3. **Product Design and Development**: Generative AI can assist in the design and development of new products, such as furniture, clothing, and even entire buildings. It can also help with product prototyping and testing.
# 4. **Music and Audio Generation**: Generative AI can create original music compositions, audio tracks, and even entire albums. This has applications in the music industry, advertising, and film production.
# 5. **Chatbots and Virtual Assistants**: Generative AI can power chatbots and virtual assistants that can understand and respond to user queries in a more human-like manner.
# 6. **Predictive Maintenance**: Generative AI can analyze sensor data from machines and predict when maintenance is required, reducing downtime and increasing overall efficiency.
# 7. **Supply Chain Optimization**: Generative AI can optimize supply chain operations by predicting demand, identifying bottlenecks, and suggesting improvements to logistics and inventory management.
# 8. **Market Analysis and Research**: Generative AI can analyze large datasets to identify trends, patterns, and insights that can inform business decisions and strategy.
# 9. **Personalized Marketing**: Generative AI can create personalized marketing campaigns based on customer behavior, preferences, and demographics.
# 10. **Cybersecurity**: Generative AI can help detect and respond to cyber threats by analyzing network traffic, identifying anomalies, and predicting potential attacks.
# 11. **Data Annotation**: Generative AI can assist with data annotation tasks such as labeling, categorizing, and enriching data, which is essential for machine learning model training.
# 12. **Customer Service**: Generative AI can power customer service chatbots that can understand and respond to customer queries in a more human-like manner.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative applications across various industries.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Generation**: AI-powered content generation tools can create high-quality content such as product descriptions, social media posts, and blog articles, freeing up human writers' time for more strategic tasks.
# 2. **Product Design**: Generative AI can be used to design products, such as 3D models, logos, and packaging designs, reducing the need for manual prototyping and design iterations.
# 3. **Marketing Automation**: AI-powered chatbots and virtual assistants can automate customer service, lead generation, and email marketing campaigns, increasing efficiency and personalization.
# 4. **Image and Video Editing**: Generative AI can be used to edit images and videos in real-time, allowing for faster content creation and post-production processes.
# 5. **Predictive Analytics**: Generative AI can analyze large datasets to identify patterns and make predictions about future trends, enabling businesses to make data-driven decisions.
# 6. **Supply Chain Optimization**: Generative AI can optimize supply chain operations by predicting demand, identifying bottlenecks, and recommending the most efficient routes for transportation and logistics.
# 7. **Customer Experience**: Generative AI-powered tools can create personalized customer experiences through chatbots, virtual assistants, and interactive content, improving customer satisfaction and loyalty.
# 8. **Creative Writing**: AI-powered writing tools can assist human writers with research, suggestions, and even full-fledged writing, helping to streamline the creative process.
# 9. **Social Media Management**: Generative AI can help manage social media presence by generating posts, responding to comments, and analyzing engagement metrics, freeing up time for more strategic tasks.
# 10. **Product Recommendation**: Generative AI-powered tools can analyze customer data and preferences to provide personalized product recommendations, increasing sales and customer satisfaction.
#
# Some specific examples of businesses using generative AI include:
#
# * **Netflix**: Uses generative AI to create personalized content recommendations
# * **Amazon**: Employs generative AI for product design, image editing, and chatbot development
# * **McDonald's**: Utilizes generative AI for automated customer service and social media management
# * **Microsoft**: Develops generative AI-powered tools for natural language processing, speech recognition, and text generation
#
# As the technology continues to evolve, we can expect to see even more innovative applications of generative AI in various industries.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative AI, also known as generative machine learning or generative models, has numerous business applications across various industries. Some of these applications include:
#
# 1. **Product Design**: Generative AI can be used to generate new product designs based on existing products and customer preferences. For example, companies like Google and Microsoft use generative AI for product design.
#
# 2.**Marketing and Branding**: Generative AI can create personalized messages, images, videos, and other marketing materials that are tailored to specific audiences, increasing the effectiveness of marketing campaigns.
#
# 3. **Content Creation**: Generative AI can generate high-quality content, such as articles, blog posts, social media posts, product descriptions, and chatbot responses, reducing the need for manual writing and editing.
#
# 4.**Customer Service Chatbots**: Generative AI-powered chatbots can understand customer inquiries and respond with personalized answers, improving the overall customer service experience.
#
# 5. **Graphic Design**: Generative AI can be used to generate images, logos, icons, and other visual assets in a faster and more efficient manner than human designers.
#
# 6.**Data Analysis**: Generative AI can analyze large amounts of data and identify patterns that might not be visible to humans, providing insights that can inform business decisions.
#
# 7. **Network Modeling**: Generative AI can simulate network behavior and predict the outcome of different scenarios, helping companies make more informed investment decisions in telecommunication networks, social media platforms, etc.
#
# 8.**Speech-to-Text and Image-to-Text Transcription**: Generative AI can improve transcription accuracy for podcasts, audiobooks, live events, and online interviews by automatically transcribing audio and video files into text.
#
# 9. **Medical Imaging Analysis**: Generative AI can be used to analyze medical images such as CT scans or MRI results to help doctors diagnose diseases more accurately.
#
# 10.**Supply Chain Optimization**: Generative AI can analyze historical data and predict future trends and behaviors, allowing companies to optimize supply chain operations for better performance and profitability.
#
# 11. **Video Editing and Creation**: Generative AI can automatically edit video footage by removing unwanted objects or scenes, adding music or effects, etc., reducing the need for manual editing time.
#
# 12.**Music Composition**: Generative AI can create original musical compositions based on existing melodies, harmonies, or lyrics, offering new perspectives on creative expression.
#
# 13. **Recommendation Systems**: Generative AI can build more sophisticated recommendation algorithms that suggest products, services, articles, etc., based on user behavior and preferences.
#
# 14.**Cybersecurity**: Generative AI can help companies detect and prevent cyber attacks by analyzing patterns of suspicious activity in their networks.
#
# 15.**Creative Writing**: Generative AI can generate new stories, poems or even entire plots based on themes, characters, genres, etc., opening up new possibilities for content creation in industries like publishing, advertising, entertainment, etc.

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.

# %%
import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI
import ollama

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
ed = Website("https://www.investorgain.com/")
print(ed.title)
print(ed.text)
# Out:
# Best Online Share Brokers in India-2025
# GMP
# IPO
# SHARE BROKERS REVIEW
# BEST BROKERS
# BROKERAGE CALCULATOR
# COMPARE BROKERS
# ×
# Mainboard IPOs
# IPO Home
# Live IPO GMP
# IPO Live Subscription
# IPO Reports
# SME IPOs
# SME IPO Home
# SME IPO Live Subscription
# NCDs
# NCDs Home
# Right Issue
# Right Issue Home
# Buyback
# Buyback Home
# Sovereign Gold Bond (SGB)
# SGB Home
# ×
# Discount Brokers
# Zerodha
# (₹20/trade)
# ProStocks
# (₹899 Per Month)
# 5paisa
# (₹20/trade)
# Upstox
# (₹20/trade)
# Angel One
# (₹20/trade)
# More Discount Brokers
# Offers & Compare
# Top 10 Discount Brokers in India
# Top 10 Stock Brokers in India
# Top 5 commodity discount brokers in India
# Special Offers
# Side by Side Compare
# FAQs
# FAQ Home
# Stock Brokers
# IPOs
# NRI Trading
# Demat
# Sovereign Gold Bond
# ×
# By Category
# Trading in India
# Lowest Brokerage
# Investment Offerings
# Customer Service
# Trading Platforms
# Monthly Plans
# NRI Trading
# 3 in 1 Account Brokers
# Demat Account
# Best Broker for Options Trading
# Zero Brokerage Trading
# 20 Rs Brokerage Account
# Commodity Trading
# More
# Popular Articles
# Unlimited Trading Plans
# Mutual Funds Direct Plan
# Zerodha Paperless account opening
# Stock for Investment
# 20 Reasons to trade with 5paisa
# More
# Other Articles
# Contract Note Comparison
# Unlimited Trading Plan ProStocks
# Multiple Trading Accounts
# NRI Trading in India
# Portfolio Management Service(PMS)
# ×
# Discount Brokers
# Zerodha
# (₹20/trade)
# ProStocks
# (₹899 Per Month)
# 5paisa
# (₹20/trade)
# Upstox
# (₹20/trade)
# Paytm Money
# (₹20/trade)
# ×
# Zerodha Vs Upstox
# Zerodha Vs 5paisa
# Zerodha Vs Groww
# Zerodha Vs Stoxkart
# 5paisa Vs Upstox
# 5paisa Vs Alice Blue
# 5paisa Vs Fyers
# Angel One Vs Groww
# Angel One Vs ProStocks
# Angel One Vs Upstox
# Angel One Vs Fyers
# Paytm Money Vs 5paisa
# Paytm Money Vs Groww
# Paytm Money Vs Zerodha
# Compare 3 brokers
# Compare 2 brokers Side by Side
# ►
# Zerodha
# Free Delivery Trade (₹20/Trade)
# Free Demat Account
# ►
# Angel One
# Free Delivery Trade
# Join Now
# ►
# Kotak Security
# ₹20/Trade
# Instant Account
# ►
# Zerodha
# Free Delivery Trade
# Free Demat Account
# ►
# AngelOne
# Free Delivery Trade
# Join Now
# Stock Broker Reviews
# Top Performing Brokers...
# Top 10 Stock Brokers in India
# Top 5 Commodity Discount Brokers
# Top 10 Discount Brokers
# More Reports...
# Discount Broker Reviews
# Zerodha
# ₹20/trade
# 5paisa
# ₹20/trade
# Upstox
# ₹20/trade
# Fyers
# ₹20/trade
# Alice Blue
# ₹15/trade
# Angel One
# ₹20/trade
# ProStocks
# ₹15/trade
# Groww
# ₹20/Trade
# HDFC Sky
# More Brokers...
# Full-service Brokers Reviews
# Axis Direct
# More Brokers...
# Compare Brokers
# Compare 3 Brokers
# ICICI Direct Vs Sharekhan
# Sharekhan Vs Angel One
# Zerodha Vs Upstox
# Zerodha vs SAMCO
# 5paisa Vs Zerodha
# Kotak Sec. Vs Hdfc Sec.
# Angel One Vs 5paisa
# Finvasia Vs Zerodha
# Fyers Vs Zerodha
# Brokers By Category
# Lowest Brokerage
# Investment Offerings
# Customer Service
# Trading Platforms
# Monthly Plans
# NRI Trading
# 3 in 1 account
# More Categories...
# Brokers Articles
# Brokerage Calculator
# FAQs
# IPO Information
# Mainboard IPO
# IPO Dashboard
# Live IPO GMP
# IPO Fundamental Analysis
# IPO Live Subscription
# IPO Reports
# SME IPO
# SME IPO Dashboard
# SME IPO Live Subscription
# Current & Upcoming Mainboard IPO
# More Mainboard IPO...
# Current & Upcoming SME IPO
# More SME IPO...
# Rights Issue
# More Right Issues ..
# Gold Bond
# Dashboard
# SGB Dashboard
# Current & Upcoming Gold Bond
# More SGB...
# Buyback
# Dashboard
# Buyback Dates
# Current & Upcoming Buyback
# More Buyback...
# NCD Issues
# More NCD Issues...
# Best Online Share Brokers in India-2025
# InvestorGain.com
# is created with the sole purpose to present the most authentic and credible source of information to all the readers. We at
# InvestorGain
# provide comprehensive, genuine, updated, and completely unbiased review of a number of
# online share brokers in India
# . It will enable clients to compare different brokerage houses on various facets like brokerage charges, products & service offerings, trading platforms, NRI trading, commodity trading, etc. and make rationalized decisions by selecting the best broker. At our portal, you can easily find the
# Best Online Brokers
# ,
# Best Brokers for NRI Trading, Best Brokers for Commodity Trading, Best Brokers with Lowest brokerage charges
# , etc. Currently, we have review of
# 30+
# discount brokers
# and 20+
# full-service brokers
# on our portal and we keep adding more and more brokers to our portfolio to serve our users in a better way.
# Our service portfolio is not just limited to brokers review as we also keep users updated with the
# latest IPOs reviews,
# Sovereign Gold Bond and Instant Personal Loan providers,
# and many relevant articles.....
# 285
# Total IPOs in FY 2024
# 258
# Positive Listing
# 27
# Negative Listing
# 105
# Above GMP Listing
# 179
# Below GMP Listing
# 1,76,576.65
# Issue Size (₹ in Cr)
# 77
# Total Mainline IPOs in FY 2024
# 69
# Positive Listing
# 8
# Negative Listing
# 33
# Above GMP Listing
# 43
# Below GMP Listing
# 1,68,334.20
# Issue Size (₹ in Cr)
# 208
# Total SME IPOs in FY 2024
# 189
# Positive Listing
# 19
# Negative Listing
# 72
# Above GMP Listing
# 136
# Below GMP Listing
# 8,242.45
# Issue Size (₹ in Cr)
# Live IPO GMP
# Issuer Company
# IPO Price
# GMP
# Est Listing
# GMP Rating
# Dr. Agarwal's BSE, NSE
# Upcoming
# 402.00
# 40
# 442 (9.95%)
# 🔥🔥
# Malpani Pipes BSE SME
# Upcoming
# 90.00
# 25
# 115 (27.78%)
# 🔥🔥🔥🔥
# H.M. Electro Mech BSE SME
# Open
# 75.00
# 24
# 99 (32%)
# 🔥🔥🔥🔥
# GB Logistics BSE SME
# Open
# 102.00
# 23
# 125 (22.55%)
# 🔥🔥🔥🔥
# Denta Water BSE, NSE
# Closed
# 294.00
# 120
# 414 (40.82%)
# 🔥🔥🔥🔥
# Latest GMP >>>
# Discount Brokers
# Zerodha
# (Flat ₹20 Per Trade in F&O)
# Max ₹20
# Angel One
# (Trade @₹20)
# Max ₹20
# 5Paisa
# (Trade @₹20)
# Max ₹20
# Upstox
# (Trade @₹20)
# Max ₹20
# Prostocks
# (Monthly Plan)
# ₹899 PM
# Open Free Demat Account
# More Info >>
# Trending SME IPOs
# Malpani Pipes
# Upcoming
# H.M. Electro Mech
# Open
# GB Logistics
# Open
# CLN Energy
# Open
# Rexpro Enterprises
# Closed
# IPO Dashboard
# SME IPO Live GMP
# IPOs Review
# Arisinfra Solutions
# Upcoming
# Dr. Agarwal's
# Upcoming
# Denta Water
# Closed
# Stallion India
# Listed
# Laxmi Dental
# Listed
# IPO Dashboard
# IPO Live GMP
# Top Performing Brokers Reports
# Rs 20 Brokerage Plan in India
# Lifetime Free Demat AMC Account
# Best Brokers for Equity SIP
# Best Online Brokers in India
# Top 10 Stock Brokers in India
# More Reports ...
# Brokers Category
# Best Brokers by Lowest Brokerage and Transaction Charges
# Best Stock Brokers for NRI Trading in India
# Best Online Brokers in India
# Best Brokers for Commodity Trading in India
# Best Brokers for Equity Trading in India
# Best Brokers for Equity SIP
# Best Brokers for Options Trading in India
# Zero Brokerage Trading Account in India
# Best Brokers for IPO investment
# Rs 20 Brokerage Account in India
# Best Stock Brokers for Demat Account in India
# Brokers Articles
# Unlimited Trading Plans or Fixed Brokerage Plans in India
# How to choose the best stock broker in India
# NRI Trading in India
# Zerodha Coin Direct Mutual Fund Investment
# How to get listed as SME company
# Mutual Fund SIP and its benefit
# More Articles ...
# Compare Brokers
# Zerodha vs Upstox
# HDFC Sky vs Zerodha
# 5paisa vs Zerodha
# Angel One vs Zerodha
# Sharekhan vs Zerodha
# Zerodha vs Fyers
# Zerodha vs AliceBlue
# Angel One vs Upstox
# 5paisa vs Upstox
# Compare 3 Brokers ...
# Our platform is for everyone whether you’re a beginner, intermediate, or expert-level trader. If you’re already a trader with any broker, then you can check the complete
# broker's review
# including its service offerings, online trading platforms, brokerage charges, etc. However, if you’re looking to start trading now, then our
# broker comparison
# feature will help you to select the most suitable broker matching your trading & investment specification.
# From time to time, we also bring many exclusive offers, so stay tuned with us to not miss the opportunity and to keep yourself updated with the ongoing market trend.
# To serve you better,
# InvestorGain
# team welcome your valuable suggestion and feedback,
# please drop it here.
# By Popular
# Stock Brokers
# Zerodha
# Rs 0 Account Opening Fee
# Free Eq Delivery & MF
# Flat ₹20 Per Trade in F&O
# Open Free Demat Account
# Angel One
# Free Equity Delivery
# Flat ₹20 Per Trade in F&O
# Open Free Demat Account
# Upstox
# Flat ₹20 Per Trade
# Free Demat Account
# Open Demat Account
# Kotak Securities
# Free Account Opening
# FREE Intraday Trading (Eq, F&O)
# Enquire Now
# 5Paisa
# Free Account Opening
# Trade at
# Flat ₹20 per Trade
# Get Free Demat Account
# Fyers
# Free Eq Delivery Trades
# Flat ₹20 Per Trade in F&O
# Open Instant Account
# Alice Blue
# Flat ₹15 Per Trade
# Most Popular Commodity Broker
# Request Instant Call Back
# CONTACT US
# SITEMAP
# ADVERTISE WITH US
# ABOUT US
# Download Mobile App
# Our Websites
# www.Chittorgarh.com
# IPO Review Portal
# www.CompareShareBrokers.com
# Best Stock Broker Reviews
# www.IPOPlatform.com
# Bring your IPO with us
# Copyright 2024-2025 by InvestorGain.com. All Rights Reserved.
# Disclaimer: InvestorGain.com has taken due care and caution in compilation of data for its web site. Information has been obtained from different sources which it considers reliable. However, InvestorGain.com does not guarantee the accuracy, adequacy or completeness of any information and is not responsible for any errors or omissions or for the results obtained from the use of such information. InvestorGain.com especially states that it has no financial liability whatsoever to any user on account of the use of information provided on its website.
# Advertiser Disclosure: We offer two types of advertising on our website. One is the display ad - broker related and IPO related. Second, we offer an affiliate links that redirects you to a stock broker's website. We have a partnership with brokers and once you become a client of a broker, we receive a affiliate relationships from the broker. We do not work with individual clients after you click on affiliate links. We do not give tips, recommendations or buy or sell calls. The information we provide on our websites is for learning and knowledge sharing purposes only. We have made completely un-biased reviews of stock brokers, we leave it up to you to choose the right stock broker for your financial needs. We provide up-to-date information on IPOs, buybacks, NCDs, SGB and rights issues on our website. We display GMP on our website for informational and news purposes only. We do not work or trade with any GMP operators.

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': "You are looking at a website titled Best Online Share Brokers in India-2025\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\nGMP\nIPO\nSHARE BROKERS REVIEW\nBEST BROKERS\nBROKERAGE CALCULATOR\nCOMPARE BROKERS\n×\nMainboard IPOs\nIPO Home\nLive IPO GMP\nIPO Live Subscription\nIPO Reports\nSME IPOs\nSME IPO Home\nSME IPO Live Subscription\nNCDs\nNCDs Home\nRight Issue\nRight Issue Home\nBuyback\nBuyback Home\nSovereign Gold Bond (SGB)\nSGB Home\n×\nDiscount Brokers\nZerodha\n(₹20/trade)\nProStocks\n(₹899 Per Month)\n5paisa\n(₹20/trade)\nUpstox\n(₹20/trade)\nAngel One\n(₹20/trade)\nMore Discount Brokers\nOffers & Compare\nTop 10 Discount Brokers in India\nTop 10 Stock Brokers in India\nTop 5 commodity discount brokers in India\nSpecial Offers\nSide by Side Compare\nFAQs\nFAQ Home\nStock Brokers\nIPOs\nNRI Trading\nDemat\nSovereign Gold Bond\n×\nBy Category\nTrading in India\nLowest Brokerage\nInvestment Offerings\nCustomer Service\nTrading Platforms\nMonthly Plans\nNRI Trading\n3 in 1 Account Brokers\nDemat Account\nBest Broker for Options Trading\nZero Brokerage Trading\n20 Rs Brokerage Account\nCommodity Trading\nMore\nPopular Articles\nUnlimited Trading Plans\nMutual Funds Direct Plan\nZerodha Paperless account opening\nStock for Investment\n20 Reasons to trade with 5paisa\nMore\nOther Articles\nContract Note Comparison\nUnlimited Trading Plan ProStocks\nMultiple Trading Accounts\nNRI Trading in India\nPortfolio Management Service(PMS)\n×\nDiscount Brokers\nZerodha\n(₹20/trade)\nProStocks\n(₹899 Per Month)\n5paisa\n(₹20/trade)\nUpstox\n(₹20/trade)\nPaytm Money\n(₹20/trade)\n×\nZerodha Vs Upstox\nZerodha Vs 5paisa\nZerodha Vs Groww\nZerodha Vs Stoxkart\n5paisa Vs Upstox\n5paisa Vs Alice Blue\n5paisa Vs Fyers\nAngel One Vs Groww\nAngel One Vs ProStocks\nAngel One Vs Upstox\nAngel One Vs Fyers\nPaytm Money Vs 5paisa\nPaytm Money Vs Groww\nPaytm Money Vs Zerodha\nCompare 3 brokers\nCompare 2 brokers Side by Side\n►\nZerodha\nFree Delivery Trade (₹20/Trade)\nFree Demat Account\n►\nAngel One\nFree Delivery Trade\nJoin Now\n►\nKotak Security\n₹20/Trade\nInstant Account\n►\nZerodha\nFree Delivery Trade\nFree Demat Account\n►\nAngelOne\nFree Delivery Trade\nJoin Now\nStock Broker Reviews\nTop Performing Brokers...\nTop 10 Stock Brokers in India\nTop 5 Commodity Discount Brokers\nTop 10 Discount Brokers\nMore Reports...\nDiscount Broker Reviews\nZerodha\n₹20/trade\n5paisa\n₹20/trade\nUpstox\n₹20/trade\nFyers\n₹20/trade\nAlice Blue\n₹15/trade\nAngel One\n₹20/trade\nProStocks\n₹15/trade\nGroww\n₹20/Trade\nHDFC Sky\nMore Brokers...\nFull-service Brokers Reviews\nAxis Direct\nMore Brokers...\nCompare Brokers\nCompare 3 Brokers\nICICI Direct Vs Sharekhan\nSharekhan Vs Angel One\nZerodha Vs Upstox\nZerodha vs SAMCO\n5paisa Vs Zerodha\nKotak Sec. Vs Hdfc Sec.\nAngel One Vs 5paisa\nFinvasia Vs Zerodha\nFyers Vs Zerodha\nBrokers By Category\nLowest Brokerage\nInvestment Offerings\nCustomer Service\nTrading Platforms\nMonthly Plans\nNRI Trading\n3 in 1 account\nMore Categories...\nBrokers Articles\nBrokerage Calculator\nFAQs\nIPO Information\nMainboard IPO\nIPO Dashboard\nLive IPO GMP\nIPO Fundamental Analysis\nIPO Live Subscription\nIPO Reports\nSME IPO\nSME IPO Dashboard\nSME IPO Live Subscription\nCurrent & Upcoming Mainboard IPO\nMore Mainboard IPO...\nCurrent & Upcoming SME IPO\nMore SME IPO...\nRights Issue\nMore Right Issues ..\nGold Bond\nDashboard\nSGB Dashboard\nCurrent & Upcoming Gold Bond\nMore SGB...\nBuyback\nDashboard\nBuyback Dates\nCurrent & Upcoming Buyback\nMore Buyback...\nNCD Issues\nMore NCD Issues...\nBest Online Share Brokers in India-2025\nInvestorGain.com\nis created with the sole purpose to present the most authentic and credible source of information to all the readers. We at\nInvestorGain\nprovide comprehensive, genuine, updated, and completely unbiased review of a number of\nonline  ...

# %%
def summarize(url):
    website = Website(url)
    response = ollama.chat(
        model = MODEL,
        messages = messages_for(website)
    )
    return response['message']['content']

# %%
summarize("https://www.investorgain.com/")
# Out:
# "InvestorGain.com is a comprehensive online platform that provides detailed reviews of stock brokers in India, including their service offerings, online trading platforms, brokerage charges, and more. The platform aims to help individuals make informed decisions when choosing a stock broker for their financial needs.\n\nKey Features:\n\n1. **Broker Comparison**: InvestorGain.com allows users to compare different stock brokers based on various parameters such as brokerage fees, transaction charges, account opening fees, and more.\n2. **Broker Reviews**: The platform provides in-depth reviews of popular stock brokers in India, including their strengths and weaknesses, customer service, and trading platforms.\n3. **IPO Information**: InvestorGain.com provides up-to-date information on IPOs (Initial Public Offerings), buybacks, NCDs (Notice Invoking Deposit), SGB (Sovereign Golden Bond), and rights issues.\n4. **GMP Tracking**: The platform displays GMP (Good Market Price) on its website for informational and news purposes only.\n\n**Popular Stock Brokers Compared:**\n\n1. Zerodha\n2. Upstox\n3. Kotak Securities\n4. 5Paisa\n5. Fyers\n6. Alice Blue\n\n**Discounts and Offers:** InvestorGain.com occasionally offers exclusive discounts and promotions to its users, which can be found on the platform's website.\n\n**Disclaimer:** The platform explicitly states that it does not work with individual clients after a user clicks on affiliate links and that all information provided is for educational purposes only."
